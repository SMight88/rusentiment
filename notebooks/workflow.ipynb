# %%
import re
import numpy as np

from nltk import tokenize, TweetTokenizer

from keras import backend as K
from keras.models import load_model

from gensim.models import KeyedVectors

from pathlib import Path

from sklearn.externals import joblib
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = Path('../data/')
EMBEDDINGS_DIR = DATA_DIR.joinpath('embeddings/')
PATH_TO_EMBEDDINGS = EMBEDDINGS_DIR.joinpath('fasttext.min_count_100.vk_posts_all_443550246.300d.vec')
PATH_TO_SCALER = DATA_DIR.joinpath('scaler.pkl')

PATH_TO_MODEL = DATA_DIR.joinpath('mlp.h5')
PATH_TO_MLB = DATA_DIR.joinpath('mlb.pkl')

# %%
class MLModel():
    
    def __init__(self):
        self.mlb = joblib.load(str(PATH_TO_MLB))
        self.model = load_model(str(PATH_TO_MODEL), custom_objects={'precision': self.precision,
                                                                    'recall': self.recall,
                                                                    'f1score': self.f1score}) 
    def precision(self, y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    def recall(self, y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def fbeta(self, y_true, y_pred, beta=1):
        if beta < 0:
            raise ValueError('The lowest choosable beta is zero (only precision).')

        # If there are no true positives, fix the F score at 0 like sklearn.
        if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
            return 0

        p = self.precision(y_true, y_pred)
        r = self.recall(y_true, y_pred)
        bb = beta ** 2
        fbeta = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta

    def f1score(self, y_true, y_pred):
        return self.fbeta(y_true, y_pred, beta=1)

# %%
class TextPreprocess():
    
    def tokenize_only(self, text):
        tokenizer = TweetTokenizer()
        text = re.sub(r'#', '# ', text)
        tokens = tokenizer.tokenize(text)
        return tokens
    
    def tokenize_with_lower(self, text):
        return [word.lower() for word in tokenize.WordPunctTokenizer().tokenize(text)]

# %%
class Embeddings():
    
    def __init__(self):
        self.embeddings = KeyedVectors.load_word2vec_format(str(PATH_TO_EMBEDDINGS))
        self.scaler = joblib.load(str(PATH_TO_SCALER))
        
    def get_vector_embeddings(self, tokens):
        embeddings_dim = self.embeddings.vector_size
        X = np.zeros((embeddings_dim), dtype=np.float32)
        empty_tokens = []
        tokens_embeddings = []
        for t in tokens:
            try:
                tokens_embeddings.append(self.embeddings.get_vector(t))
            except KeyError:
                tokens_embedding = self.get_embeddings_of_error_token(t, tokens_embeddings, empty_tokens)
        if len(tokens_embeddings) > 0:
            mean_embeddings = np.mean(tokens_embeddings, axis=0)
            X = mean_embeddings
        if len(empty_tokens) > 0:
            print(f'Empty tokens: {empty_tokens}')
        return X
    
    def get_embeddings_of_error_token(self, token, tokens_embeddings, empty_tokens):
        tokens = textpreprocess.tokenize_with_lower(token)
        for t in tokens:
            try:
                tokens_embeddings.append(self.embeddings.get_vector(t))
            except KeyError:
                empty_tokens.append(t)
        return tokens_embeddings

# %%
# %%time

mlmodel = MLModel()
textpreprocess = TextPreprocess()
embeddings = Embeddings()
# Out:
# CPU times: user 2min 15s, sys: 1.76 s, total: 2min 17s
# Wall time: 2min 17s

# %%
text = 'всё так хорошо!'

# %%
text_tok = textpreprocess.tokenize_only(text)
text_vec = embeddings.get_vector_embeddings(text_tok)
# text_vec_scale = embeddings.scaler.transform(text_vec.reshape(1, 300))
text_vec_scale = embeddings.scaler.transform(text_vec.reshape(1, int(embeddings.embeddings.vector_size)))

# %%
pred = mlmodel.model.predict(text_vec_scale)[0]

# %%
max_pred = max(pred)
max_pred_position = np.where(pred==max_pred)[0][0]
mlmodel.mlb.classes_[max_pred_position]
# Out:
# 'positive'

# %% [markdown]
# # Testing

# %%
import pandas as pd
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
DATASET_DIR = DATA_DIR.joinpath('dataset/')

# %%
df_test = pd.read_csv(DATASET_DIR.joinpath('rusentiment_test.csv'))

# %%
samples_test = []
for message in df_test.text:
    samples_test.append(textpreprocess.tokenize_only(message))
    
labels_test = df_test.label.values

# %%
X_test = []
for sample in samples_test:
    X_test.append(embeddings.get_vector_embeddings(sample))
# Out:
# Empty tokens: [':)']
# Empty tokens: ['id12210212', 'елисеем']
# Empty tokens: ['самоунижение']
# Empty tokens: ['мангаром']
# Empty tokens: ['оскобление']
# Empty tokens: ['ксюху']
# Empty tokens: ['жевто', 'блакитные']
# Empty tokens: ['отнятых']
# Empty tokens: ['каверн', 'каверна']
# Empty tokens: ['сейчааас']
# Empty tokens: ['hardy']
# Empty tokens: ['превередлевый']
# Empty tokens: ['куринов']
# Empty tokens: ['"', '"']
# Empty tokens: ['шерхана', '=)']
# Empty tokens: [':-)']
# Empty tokens: [';)', ':)']
# Empty tokens: ['zufällig', 'supermarkt', 'zufällig']
# Empty tokens: ['люблюкогда']
# Empty tokens: ['заболiв']
# Empty tokens: ['извращёная']
# Empty tokens: ['🏻']
# Empty tokens: ['субтропиков']
# Empty tokens: ['"', 'морозною', '"']
# Empty tokens: ['id27975702']
# Empty tokens: ['трансхондральный', 'медиального', 'крестообразной', 'подколенной']
# Empty tokens: ['"', '"', 'соленоетесто']
# Empty tokens: ['протоптанные']
# Empty tokens: ['южке']
# Empty tokens: [':)']
# Empty tokens: ['разрешающая']
# Empty tokens: ['анахронизмом', 'изжившего', 'пережитка']
# Empty tokens: ['едийствиная']
# Empty tokens: ['гавнистого']
# Empty tokens: ['армииин']
# Empty tokens: ['пожизне']
# Empty tokens: ['сфотает']
# Empty tokens: [':)']
# Empty tokens: ['кактайся']
# Empty tokens: ['печенён']
# Empty tokens: ['пивыч', '):']
# Empty tokens: ['"', '"', '"', '"', '"', 'мёртвенькую', '"', '"', '"']
# Empty tokens: ['стааас']
# Empty tokens: ['"', 'калюки', '"', '"', '"', 'грамотея', 'борщевика', 'кромсаю', ':)', 'калюка', 'обертоновая', 'полых', 'борщевиков', 'дудников']
# Empty tokens: ['жарева']
# Empty tokens: ['апйать']
# Empty tokens: ['гарнюньо']
# Empty tokens: ['сацепдус', ':)']
# Empty tokens: ['сфотографируете', '"', '"', '"', '"', 'какпохудеть', 'kangooclubdnepropetrovsk', 'легкохудеем']
# Empty tokens: ['"']
# Empty tokens: ['lаcoste']
# Empty tokens: ['=)']
# Empty tokens: ['надь']
# Empty tokens: ['):']
# Empty tokens: ['=)']
# Empty tokens: ['id12378670']
# Empty tokens: ['=)', '=)']
# Empty tokens: ['мулатки', 'милионеры', 'чарлстон', '"', '"']
# Empty tokens: ['научишса']
# Empty tokens: ['забалела']
# Empty tokens: ['отдельнaя', 'комнaтa', 'вaрит']
# Empty tokens: ['fабрика']
# Empty tokens: ['вуктыле']
# Empty tokens: [':)']
# Empty tokens: ['спросоня', 'вашингтоне', ':)']
# Empty tokens: ['наглотались', '=(', 'былааа', '"']
# Empty tokens: ['койве']
# Empty tokens: [';)']
# Empty tokens: ['перуанец', '"', '"', '"', '"', ':)']
# Empty tokens: ['"', 'кормлюсь', '"']
# Empty tokens: ['лидскиго', 'предсавителей', 'алкоголизированных', 'преподователям', 'оуденховену', 'силлевис', 'ковалевской', 'пашкевичу', 'коврову']
# Empty tokens: ['валерона']
# Empty tokens: ['"', '"']
# Empty tokens: ['скучилааа']
# Empty tokens: ['объедения', 'молдавии', 'румынии']
# Empty tokens: ['рафаеллам']
# Empty tokens: [':)']
# Empty tokens: ['дисковом']
# Empty tokens: ['предмодульное', 'тгпшное']
# Empty tokens: ['лану']
# Empty tokens: ['"', '"']
# Empty tokens: ['сялямя']
# Empty tokens: ['кисюн']
# Empty tokens: ['"', '"', 'тотемского']
# Empty tokens: ['id121637369', 'id25098301', 'id13575830']
# Empty tokens: [':)']
# Empty tokens: ['отучишься', 'навариватся']
# Empty tokens: ['промильного', 'тартрата', 'диэтиламида', 'тартрата', 'разбавлен']
# Empty tokens: ['выблядские']
# Empty tokens: ['"', '"']
# Empty tokens: ['латиносами']
# Empty tokens: ['прорубит']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['буф']
# Empty tokens: ['воскресна']
# Empty tokens: [':)']
# Empty tokens: ['созвонилась']
# Empty tokens: ['сднемрожденьяуважаемыйтынашчеловекуспеховдобраростабудьмолодцом']
# Empty tokens: ['помазанную', 'джоуша', 'синагогой', 'благословенному']
# Empty tokens: ['состоятельней']
# Empty tokens: ['солцем', 'мехико', 'фиесты', 'сеньоритам', 'hocico']
# Empty tokens: ['"', 'тритоном', '"']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['"', 'аалло', '"']
# Empty tokens: ['драгонфрут', 'аннона', 'чешуйчатая', 'florentine']
# Empty tokens: ['09552028']
# Empty tokens: [':)']
# Empty tokens: ['богохульствуй']
# Empty tokens: ['полуничка']
# Empty tokens: ['маан']
# Empty tokens: ['полнэ', 'жопэ']
# Empty tokens: [':)', ':)', ':)', ';)']
# Empty tokens: ['запотевает', 'закачке']
# Empty tokens: ['моядоча', 'губкипююю']
# Empty tokens: ['петрроманов', 'отчественный', 'chrisevans', 'фапательных']
# Empty tokens: ['прадам', 'краснаю', 'брусь', 'секвою', 'паставлю']
# Empty tokens: ['намжима', '=(']
# Empty tokens: ['алкино']
# Empty tokens: ['селяя']
# Empty tokens: ['иоанновичу', 'шуйскому']
# Empty tokens: ['еееесть', 'усииик']
# Empty tokens: ['кощея', 'пожирателя']
# Empty tokens: ['засосс']
# Empty tokens: ['патисоны', 'присаливаешь', 'специйками', 'оттянешь', 'хрумстит', 'морковочка', 'кисловатеньким', 'сыроедами']
# Empty tokens: ['шенгеном']
# Empty tokens: ['фуркаду']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['размажут']
# Empty tokens: ['уилкс']
# Empty tokens: ['🗓', 'аааатлично', 'аааафигенно']
# Empty tokens: ['посотрудничать', ';)']
# Empty tokens: ['id17937441', 'бооольшое']
# Empty tokens: [':)', 'многоборья', 'малокровья', 'морковий']
# Empty tokens: ['пруыфы']
# Empty tokens: ['вернисссььь']
# Empty tokens: [':)', ':)']
# Empty tokens: [':)']
# Empty tokens: ['10805594', 'артам']
# Empty tokens: ['"', '"']
# Empty tokens: ['свага', 'свага', 'mrtearax', '=)']
# Empty tokens: ['вблизь', '"', '"', 'дурманный', 'искав', '"', '"']
# Empty tokens: ['жгиии']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['видеоинструкции']
# Empty tokens: ['id7087884', 'sarikone', 'фейлами', ':)']
# Empty tokens: ['сливов', 'здароуя', 'грошау', '::', ':)']
# Empty tokens: [':)']
# Empty tokens: ['фапный']
# Empty tokens: ['омьаваяйся']
# Empty tokens: ['🗣', '🏼', 'утеплиться', '🏻']
# Empty tokens: ['"', '"']
# Empty tokens: ['фермерская']
# Empty tokens: ['черноморск']
# Empty tokens: [';)']
# Empty tokens: ['ильяхов']
# Empty tokens: ['адье']
# Empty tokens: [':)']
# Empty tokens: ['кааа']
# Empty tokens: ['втрескался']
# Empty tokens: ['майдаунцам']
# Empty tokens: ['заляпал']
# Empty tokens: ['merlinflashmob', 'приглашенная', 'меллинг', '"', 'дадлик', '"', 'похудал']
# Empty tokens: ['доходился']
# Empty tokens: [':)']
# Empty tokens: ['megatest']
# Empty tokens: ['хуипа']
# Empty tokens: ['"', 'нуёрк', 'таймз', '"']
# Empty tokens: ['лидусь']
# Empty tokens: ['старикхэм', 'thebajikans']
# Empty tokens: [':)', ':)']
# Empty tokens: ['секретки']
# Empty tokens: ['evgeny_t']
# Empty tokens: ['ахтари', 'таранухи', 'немутной', 'паленки', 'ядроного']
# Empty tokens: ['sociosoft', 'методическое', '"', '"']
# Empty tokens: ['битловское']
# Empty tokens: ['пятизвездочные']
# Empty tokens: ['медиаконтентом']
# Empty tokens: [':*:']
# Empty tokens: ['яхххууу']
# Empty tokens: ['ночьюна']
# Empty tokens: ['заюньчик']
# Empty tokens: ['раффаэльчика']
# Empty tokens: ['литара', 'талитари']
# Empty tokens: [':)']
# Empty tokens: ['синоптиках']
# Empty tokens: ['адско', 'админить', 'жопорезу', 'запрудни']
# Empty tokens: ['роися', '2018г']
# Empty tokens: ['sonnyfalcone', ':)']
# Empty tokens: ['покивать', 'id30853655']
# Empty tokens: ['пересадовка']
# Empty tokens: ['покорено', '"', '"']
# Empty tokens: ['=)']
# Empty tokens: ['всосало']
# Empty tokens: ['"', '"']
# Empty tokens: ['вум']
# Empty tokens: ['ураааеще']
# Empty tokens: ['"', '"']
# Empty tokens: ['id49662827', 'мазефукеер']
# Empty tokens: ['"', '"']
# Empty tokens: ['groovelife', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['нахуа']
# Empty tokens: [':)']
# Empty tokens: ['обочное']
# Empty tokens: ['мегаваланче']
# Empty tokens: ['=)']
# Empty tokens: ['=)']
# Empty tokens: [':-)']
# Empty tokens: ['возвращеницем']
# Empty tokens: ['"', '"']
# Empty tokens: ['посекретничать']
# Empty tokens: ['дцм']
# Empty tokens: ['"', '"', '"', '"', '"', '"', ':)']
# Empty tokens: ['"', '"']
# Empty tokens: ['мнемонике']
# Empty tokens: ['лорфелен']
# Empty tokens: [':)']
# Empty tokens: ['повешением']
# Empty tokens: ['спляжауходимпоследние']
# Empty tokens: ['"', '"']
# Empty tokens: ['самоволкууу']
# Empty tokens: [':)']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['яицами']
# Empty tokens: ['кацка']
# Empty tokens: ['rb014976210cn']
# Empty tokens: ['дедыну']
# Empty tokens: ['"', '"', ':)']
# Empty tokens: ['сдааал']
# Empty tokens: ['трёхметровых', 'трёхметровыми', 'непостяжимо']
# Empty tokens: ['деммм']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['=-)']
# Empty tokens: ['кокошка']
# Empty tokens: ['14х19']
# Empty tokens: ['обмельчал']
# Empty tokens: ['носк', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['нечегооо']
# Empty tokens: ['министерское']
# Empty tokens: ['=)']
# Empty tokens: ['id31552783', 'тетен', 'раенка']
# Empty tokens: ['каджиты']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['=)']
# Empty tokens: ['юлка']
# Empty tokens: ['планируеться']
# Empty tokens: [':)', ':)', ':)', ':)', ':)']
# Empty tokens: ['агутин', 'zhemchuzhina']
# Empty tokens: ['"', '"', '"', '"', '"', '"', 'факеры']
# Empty tokens: ['"', 'обеги', 'перекувырнись', 'проделай', 'взберись', 'плакальщика', '"']
# Empty tokens: ['смоогла', 'крека']
# Empty tokens: ['косноязычный']
# Empty tokens: ['вадькооо']
# Empty tokens: ['соображается']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['=)']
# Empty tokens: ['градоначальницкой', 'перестраиваясь', 'полосной', 'мопеду', 'двигавшемуся', 'доспустил', 'вызывалось', 'вызывалась', 'сэмпо', '2012073']
# Empty tokens: ['ладогафест']
# Empty tokens: ['игромира', 'vsp', 'донатерам']
# Empty tokens: ['трася', 'трася']
# Empty tokens: ['"', '"', '->', 'app3333333_176634666']
# Empty tokens: [';)']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['осьминожек']
# Empty tokens: [':)']
# Empty tokens: ['ситцевою']
# Empty tokens: ['"', '"']
# Empty tokens: ['еееееб']
# Empty tokens: ['"', '"']
# Empty tokens: ['"', '"', '"', '"', ':)']
# Empty tokens: ['нуук']
# Empty tokens: ['добровольский']
# Empty tokens: ['михайли']
# Empty tokens: ['годомо']
# Empty tokens: ['шетает']
# Empty tokens: ['надменными']
# Empty tokens: [':)']
# Empty tokens: ['лезби']
# Empty tokens: [':)']
# Empty tokens: ['понили']
# Empty tokens: ['чшо']
# Empty tokens: ['гречкометр']
# Empty tokens: ['началиничек']
# Empty tokens: ['тортикам']
# Empty tokens: ['полушарье']
# Empty tokens: ['алехандре']
# Empty tokens: ['"', '"']
# Empty tokens: ['сверхраса']
# Empty tokens: ['невздумай']
# Empty tokens: ['францух']
# Empty tokens: ['помойный']
# Empty tokens: ['"', '"']
# Empty tokens: ['прокричаться', 'полутешествовать']
# Empty tokens: [';-)']
# Empty tokens: ['пролайкайте']
# Empty tokens: ['билаал']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['амон', 'кабася']
# Empty tokens: ['невзоров']
# Empty tokens: ['гелиосов']
# Empty tokens: ['app4823858_207601543', 'хренасе']
# Empty tokens: ['"', '"', '->', 'app3333333_157872976']
# Empty tokens: [':)']
# Empty tokens: ['поминовением', 'благоустроителя', '"', '"', 'вологжанам', 'сорокового', '"', '"', '6390', '0212', '9003', '2518', 'скворцовой']
# Empty tokens: [':)']
# Empty tokens: ['кенгурятник', 'сссукккиии']
# Empty tokens: ['pavlenko_alexander']
# Empty tokens: ['кисии']
# Empty tokens: ['14680']
# Empty tokens: ['hohner', 'эбенового', 'яблофон']
# Empty tokens: ['алтуфьевским', 'осташковским']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['возращений']
# Empty tokens: ['ваввв']
# Empty tokens: [':)']
# Empty tokens: ['мавродия', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['высмотрела']
# Empty tokens: ['пытaйся', 'стaрaйся']
# Empty tokens: ['масиськи']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['воскрее', 'воистенну', 'агаи']
# Empty tokens: [':)']
# Empty tokens: ['"', '"', 'пираткам']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['нивелированию']
# Empty tokens: ['ахалтекинца', 'засиживаниями', 'отливкой']
# Empty tokens: ['отбросыыы']
# Empty tokens: [':)']
# Empty tokens: ['"', 'чизбургере', '"']
# Empty tokens: ['дубнячок']
# Empty tokens: ['дааам', 'сексистов']
# Empty tokens: ['запихаешь']
# Empty tokens: ['памажите']
# Empty tokens: [':)']
# Empty tokens: ['спетая']
# Empty tokens: ['кошмак', 'ходаченко']
# Empty tokens: ['субары']
# Empty tokens: ['"', '"']
# Empty tokens: ['многогрешную']
# Empty tokens: ['реанимировал']
# Empty tokens: [':)']
# Empty tokens: ['абсурде']
# Empty tokens: ['дубар']
# Empty tokens: ['сявотааа', 'id33805566', 'id25643185']
# Empty tokens: ['облысеешь', ';)']
# Empty tokens: ['хромоногих']
# Empty tokens: ['кскц', ':)']
# Empty tokens: ['мтэка', 'id2038962', 'id10002024', 'карча', 'id182283512', 'id10498468', 'крузитова', 'id5709274', 'id49578944', 'кармакских', 'id3665093', 'id6219204', 'зинатуллина', 'id1747294', 'сабирзянов', 'id2089318']
# Empty tokens: [':(']
# Empty tokens: ['"', 'малыхин', 'ляшковец', 'азовмаша']
# Empty tokens: ['الجسمي', 'بشرة', 'حصريا']
# Empty tokens: ['маринованным']
# Empty tokens: ['проапгрейдили']
# Empty tokens: [';)']
# Empty tokens: ['крошкааа', 'козааа']
# Empty tokens: ['многопоточного', 'многопоточного']
# Empty tokens: ['сыыыноооккк']
# Empty tokens: [':)']
# Empty tokens: ['беловы']
# Empty tokens: ['одновидео']
# Empty tokens: ['уубун', 'хамматым']
# Empty tokens: ['пройденно']
# Empty tokens: ['ачивмент', 'анлокд', 'мсьё', 'буевича']
# Empty tokens: ['ахахахахахахахаххаха']
# Empty tokens: ['прибулець']
# Empty tokens: ['poexali']
# Empty tokens: [':)']
# Empty tokens: ['17летие', ':)', ':*:']
# Empty tokens: ['бухахаль']
# Empty tokens: ['свентовит', 'святовит', 'свентовит', 'годичных', 'ярило', 'купайла', 'световит', '"', 'праведы', '"', '"', '"', '15260032', '_163831503']
# Empty tokens: ['сиграйем']
# Empty tokens: ['ширке']
# Empty tokens: ['"', '"']
# Empty tokens: [';)']
# Empty tokens: ['=)']
# Empty tokens: ['наперся']
# Empty tokens: ['сыыhатын', 'билинэр', '5ына', 'бастакынан', 'бэйэтэ', 'чугаhаыхтаах']
# Empty tokens: ['🏻']
# Empty tokens: ['рамашка']
# Empty tokens: ['находские', 'беспризорники']
# Empty tokens: ['гомесу']
# Empty tokens: ['мммляяя']
# Empty tokens: ['подымающихся', 'быдлятство', 'изживем']
# Empty tokens: [':)']
# Empty tokens: ['хавкой']
# Empty tokens: ['"', '"', '"', 'пентаграмме']
# Empty tokens: ['пристов']
# Empty tokens: ['холодноноклассно']
# Empty tokens: [':-}', 'пятёру', ':-}']
# Empty tokens: ['"', 'перегибал', '"']
# Empty tokens: ['mowar']
# Empty tokens: ['bbcos', 'bbcos']
# Empty tokens: ['владимировичи']
# Empty tokens: ['киноежика']
# Empty tokens: ['звездабол']
# Empty tokens: ['):']
# Empty tokens: ['"', '"', 'рюшечку']
# Empty tokens: ['28weeks', 'ждемтретьего', 'многодетейнебывает']
# Empty tokens: ['повешал']
# Empty tokens: [':)']
# Empty tokens: ['пятаке']
# Empty tokens: ['ᅠᅠᅠ', 'ᅠᅠᅠугу']
# Empty tokens: ['пенчи']
# Empty tokens: ['4изюм']
# Empty tokens: ['рэмпэйджа']
# Empty tokens: ['роналдооо']
# Empty tokens: ['славко']
# Empty tokens: ['понаприлетали']
# Empty tokens: ['"', '"', '"', 'филиппок', '"']
# Empty tokens: ['фоня']
# Empty tokens: ['"', '"']
# Empty tokens: ['кренделёк', 'амеги']
# Empty tokens: ['фоловить']
# Empty tokens: [';)']
# Empty tokens: ['турклубом', '):']
# Empty tokens: ['кружащиеся']
# Empty tokens: ['микстерша']
# Empty tokens: ['=*(']
# Empty tokens: ['фиху']
# Empty tokens: ['полыхающими']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['пахин', 'убаханых', 'гетанонит']
# Empty tokens: ['джордисон', 'отсосе']
# Empty tokens: ['велопробежку']
# Empty tokens: ['уранил']
# Empty tokens: ['дохлости', 'ковыряете', 'палеонтологией', ';-)']
# Empty tokens: [':(']
# Empty tokens: ['плющев', '"', '"']
# Empty tokens: ['3769976']
# Empty tokens: ['милочке']
# Empty tokens: ['elcomsoft']
# Empty tokens: ['побелку']
# Empty tokens: ['затестив', 'камерку']
# Empty tokens: ['девкиии']
# Empty tokens: ['посдравляю']
# Empty tokens: ['отданного', '"', '"', 'угарнул', '"', '"', 'угарнул', ':)']
# Empty tokens: ['toyo', 't1r', 'повседнев']
# Empty tokens: ['ссыльным']
# Empty tokens: [':)']
# Empty tokens: ['страшенной']
# Empty tokens: ['иобнимашки']
# Empty tokens: [':)', ':)']
# Empty tokens: [';)']
# Empty tokens: ['поебатся', ':)']
# Empty tokens: ['токийские']
# Empty tokens: [':*:']
# Empty tokens: [':)']
# Empty tokens: ['бастард', 'valravn']
# Empty tokens: ['богиииня']
# Empty tokens: ['аххаахаххахаха']
# Empty tokens: ['лакера', 'рулетках', 'альты', 'csgoshuffle', 'итемы']
# Empty tokens: ['озо']
# Empty tokens: ['=)']
# Empty tokens: [':)']
# Empty tokens: ['🔩', '🛠', '⚙']
# Empty tokens: ['кумеее', ':)']
# Empty tokens: ['мироном']
# Empty tokens: [':)']
# Empty tokens: ['попудчиков']
# Empty tokens: ['альхамдулиллах']
# Empty tokens: ['попсятинку']
# Empty tokens: ['раздолбана', 'проканало']
# Empty tokens: ['):']
# Empty tokens: ['демаршелье', 'феш']
# Empty tokens: ['(=']
# Empty tokens: ['конату', 'оседку']
# Empty tokens: ['ахахахахахахахх', '"', 'mitya', '"']
# Empty tokens: ['пупей']
# Empty tokens: ['милашкамашка']
# Empty tokens: ['тагыда', '🛍']
# Empty tokens: ['аутисту']
# Empty tokens: ['прохер', 'трисемерочки', 'русрок']
# Empty tokens: ['блондинкавзаконе']
# Empty tokens: ['фошыст']
# Empty tokens: ['хореографическому', '"', '"', ':-)']
# Empty tokens: ['тусёна']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['армана', 'baik']
# Empty tokens: ['полсрока']
# Empty tokens: [':*:']
# Empty tokens: ['::', 'байбородин', '::', 'урукхай', '::']
# Empty tokens: ['6plus', 'лопатина', 'сгибаемость']
# Empty tokens: ['"']
# Empty tokens: ['"', '"']
# Empty tokens: ['обессудят']
# Empty tokens: ['сушидома']
# Empty tokens: ['рождествескими', ':)']
# Empty tokens: ['bansko']
# Empty tokens: ['бигус']
# Empty tokens: ['завьяловой', 'пистимеи', '"', '"']
# Empty tokens: ['дeвчёнки', 'дублёнки', 'нaхуя', 'египтe', 'турцыи']
# Empty tokens: ['засвищут']
# Empty tokens: ['icebucketchallengе', 'эльвире', 'ахмедовой', 'добрыниной']
# Empty tokens: ['максимовой', 'копр', 'гематологическое']
# Empty tokens: ['загружаюсь', 'леталку']
# Empty tokens: ['=)', 'защитившая']
# Empty tokens: ['поплясали']
# Empty tokens: ['лубоов']
# Empty tokens: ['когдаделатьнечего', 'такиехорошиевыходные']
# Empty tokens: ['замороченный']
# Empty tokens: ['нойера']
# Empty tokens: ['"', 'юкебокс', '"']
# Empty tokens: [':)']
# Empty tokens: ['п1сню']
# Empty tokens: ['"', '"', ';)']
# Empty tokens: [':)']
# Empty tokens: ['пррробежка']
# Empty tokens: ['"', '"', '"', 'vnoge', '"', 'imovie']
# Empty tokens: ['пидуру']
# Empty tokens: [':)', ':)']
# Empty tokens: ['fashy']
# Empty tokens: ['шнива', 'бтд', 'стиллавиным']
# Empty tokens: ['ахахахахаххх']
# Empty tokens: ['=)']
# Empty tokens: [':)']
# Empty tokens: ['досадили', ';)']
# Empty tokens: ['передержали']
# Empty tokens: ['статусище']
# Empty tokens: ['музака']
# Empty tokens: ['лучницу']
# Empty tokens: ['майданауты']
# Empty tokens: ['бейлисом', 'ингридиентах']
# Empty tokens: [':)']
# Empty tokens: ['=)', '=)']
# Empty tokens: ['🇺', 'new_star_tv', '🇮', '🇹', 'mosca', 'amichi']
# Empty tokens: [':)']
# Empty tokens: ['лимитированный']
# Empty tokens: ['козззааа']
# Empty tokens: ['7мь', ':)', ':)']
# Empty tokens: ['сьомка']
# Empty tokens: ['заспамят']
# Empty tokens: ['креслицем', 'басовито', 'тыртыртыр', '=)', 'гонцать', 'стартрек', ':)', 'круизер']
# Empty tokens: [';)']
# Empty tokens: ['настырыанньа']
# Empty tokens: [':)']
# Empty tokens: ['райс']
# Empty tokens: ['"']
# Empty tokens: ['прикольненькие']
# Empty tokens: ['рвеее']
# Empty tokens: ['муромский']
# Empty tokens: ['антистатично', 'ниипп']
# Empty tokens: ['лачетти']
# Empty tokens: ['потренил']
# Empty tokens: ['джипперы']
# Empty tokens: ['id3619867', 'симом']
# Empty tokens: ['коэн']
# Empty tokens: [';)']
# Empty tokens: [':)']
# Empty tokens: ['режимщиком', 'араратом', 'предрасположенностью', 'авторитарному', 'удвительного', 'параноидальную', 'возвеличиванию', 'однозначо', 'самовлюблённости']
# Empty tokens: ['id125431346']
# Empty tokens: ['cтерва']
# Empty tokens: ['id5430162']
# Empty tokens: ['"', 'исторично', '"']
# Empty tokens: ['"']
# Empty tokens: ['запилим', 'амиги']
# Empty tokens: ['токарного', 'сельскхозяйства', 'слизанной']
# Empty tokens: [':)']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['"', '"', 'сфабриковавшие']
# Empty tokens: ['морозица']
# Empty tokens: ['трiшки']
# Empty tokens: ['хахахахахахахахахахахахахахаххахахахах']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['id1631169']
# Empty tokens: ['ахахвхвхахахбхахахахбхахахбхахахахахахбхахбха']
# Empty tokens: ['продажний']
# Empty tokens: ['marakesha89', 'skillup']
# Empty tokens: ['ленские', 'карая']
# Empty tokens: ['мувер']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: [';)']
# Empty tokens: ['=)']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"']
# Empty tokens: ['"', '"', '"', 'варраву', '"']
# Empty tokens: [':)']
# Empty tokens: ['пусыми', 'изобильным', '"', 'сердечексмайликовкотиков', '"', 'скопированые', 'записать_все_в_бессмысленных_странных_хэштегах']
# Empty tokens: ['вирап']
# Empty tokens: ['ботекса']
# Empty tokens: ['мастерком']
# Empty tokens: ['"', '"', '"', '"', '"', '"', 'раскланиваются', 'высокогорные', 'киргизята', ':)']
# Empty tokens: ['шосливого', ':)']
# Empty tokens: ['перекричали']
# Empty tokens: ['просвещающим', '🏻']
# Empty tokens: ['indy']
# Empty tokens: ['=)']
# Empty tokens: ['стрижемся', 'bigbroth']
# Empty tokens: ['каать']
# Empty tokens: ['пронизывал', 'сломиться']
# Empty tokens: ['мятёжных', 'фридона', 'надда']
# Empty tokens: ['конса']
# Empty tokens: ['межвидовому', 'скрещиванию']
# Empty tokens: ['=)']
# Empty tokens: ['настьяя']
# Empty tokens: [':)']
# Empty tokens: ['дружой']
# Empty tokens: ['зарегается', 'seosprint', '/?', '1550891ссылке']
# Empty tokens: ['креативов']
# Empty tokens: ['хабаровчане', 'орудующего']
# Empty tokens: ['"', '"']
# Empty tokens: ['нacтоящaя']
# Empty tokens: [':)', ':)']
# Empty tokens: ['дзара']
# Empty tokens: ['прилагающимися']
# Empty tokens: ['другаче']
# Empty tokens: ['грубиянов']
# Empty tokens: ['"', '"']
# Empty tokens: ['бэттла']
# Empty tokens: ['белухе', '"', '"']
# Empty tokens: ['изуверство', 'изуверство', 'рукописной']
# Empty tokens: ['7money']
# Empty tokens: ['оттрапезничать']
# Empty tokens: [';)']
# Empty tokens: ['"', '"']
# Empty tokens: ['мадейру']
# Empty tokens: ['открещиваешься']
# Empty tokens: ['id137937531', 'нааастюююшааа', 'компма', 'сучяра']
# Empty tokens: ['"', '"', '"', '"', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['"', '"', 'рэю']
# Empty tokens: ['sapphires', 'poccия']
# Empty tokens: ['сенсацииия', 'голосуееем', 'gungsta']
# Empty tokens: ['нeробиться']
# Empty tokens: ['"', '"']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['заглушечки', '"', '"']
# Empty tokens: ['пожелтеть', 'зажралось', 'нонешнее']
# Empty tokens: ['заебенная']
# Empty tokens: ['мастурбирен', 'порноста']
# Empty tokens: ['арабисты', 'командировочка', 'расспросите']
# Empty tokens: ['земфирное']
# Empty tokens: ['"', '"']
# Empty tokens: ['angel_care']
# Empty tokens: ['вспомнииим', 'крутууую']
# Empty tokens: ['изени', 'поноси', 'различей']
# Empty tokens: ['"', '"']
# Empty tokens: ['=)', '=)']
# Empty tokens: ['катое', 'насамам']
# Empty tokens: ['сазон']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['=)']
# Empty tokens: ['максидрома']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['йаааууу']
# Empty tokens: ['пратиш']
# Empty tokens: ['trbls']
# Empty tokens: ['чудестным']
# Empty tokens: ['=)']
# Empty tokens: ['переросший', '"', '"']
# Empty tokens: ['кьево']
# Empty tokens: ['обогащенная', '"', '"', '"', '"', '"', '"', '3809797543']
# Empty tokens: ['тахтиева']
# Empty tokens: ['=)']
# Empty tokens: ['интерессная', 'синима']
# Empty tokens: [':)']
# Empty tokens: ['видеографом']
# Empty tokens: [':)']
# Empty tokens: ['неозоримое']
# Empty tokens: ['франковс']
# Empty tokens: ['клубняки', 'wap', 'kengu']
# Empty tokens: [';)']
# Empty tokens: ['сундучёк']
# Empty tokens: ['):']
# Empty tokens: ['ломлюсь']
# Empty tokens: ['гортитесь']
# Empty tokens: [';)']
# Empty tokens: ['стесняющиеся', 'id4294233', 'id19124017']
# Empty tokens: ['хренали']
# Empty tokens: ['впараллельнойвселенной']
# Empty tokens: ['"', '"']
# Empty tokens: ['данюююля']
# Empty tokens: ['святотатств']
# Empty tokens: ['=)']
# Empty tokens: ['крюков']
# Empty tokens: ['"', '"']
# Empty tokens: ['хелпера', 'ogyrochek', 'серву', 'дюпе', 'гибридок', 'пасику', '"', 'хелпера', '"', 'потомуш']
# Empty tokens: ['саркельского', 'позолитить', 'позолочу']
# Empty tokens: ['роа']
# Empty tokens: ['судовладелец', 'bogomaz']
# Empty tokens: ['опаса', 'суцка']
# Empty tokens: [';-)']
# Empty tokens: ['нравитьсяя']
# Empty tokens: ['теплыййй', 'кененбелян']
# Empty tokens: [':)', 'британскиекотята', 'вислоухиекотята', 'котятвыбирайте']
# Empty tokens: ['"', '"']
# Empty tokens: ['бодибилдир', 'фельтикультяпистого', 'выбоинам', 'видавшая', ':)']
# Empty tokens: ['дайт']
# Empty tokens: ['восьмибитной', '"', '"', '"', 'тыгыдымский', '"', ':)']
# Empty tokens: ['выпусконой', '"', '"']
# Empty tokens: [':)']
# Empty tokens: ['комедианты']
# Empty tokens: ['поопасней']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"']
# Empty tokens: ['стейнбека', 'длиннющее', 'лисман', 'силаковой']
# Empty tokens: ['бабехи']
# Empty tokens: ['хэтфилда']
# Empty tokens: ['лааадочка']
# Empty tokens: ['proza', 'sedoi']
# Empty tokens: ['квиз', '=)']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"', 'передергиваний', 'передергивание', '"', 'электродинамики', '"', 'юмба']
# Empty tokens: ['"', 'утомленного', 'отчаявшегося', 'удрученного', '"']
# Empty tokens: ['депешистов', 'гахана']
# Empty tokens: ['тащем', 'склейка', 'интерпретированный']
# Empty tokens: ['дтш']
# Empty tokens: ['этууу']
# Empty tokens: ['изменщииикк']
# Empty tokens: ['бандерложье', 'правительсьво']
# Empty tokens: ['восхищённые']
# Empty tokens: ['exprussia', 'сердцегорода', 'sputnikru']
# Empty tokens: ['рроссии']
# Empty tokens: [';)', 'id584055', 'id1628518', 'засняться', ';)']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['8937419876']
# Empty tokens: ['перекривили', '"', 'комбинациям', '"']
# Empty tokens: ['зиле']
# Empty tokens: [':)']
# Empty tokens: ['акаля']
# Empty tokens: ['обнимеш', 'падойдёш', 'утешиш']
# Empty tokens: ['накачаных', '=)']
# Empty tokens: ['калбаситесь', 'мечетни']
# Empty tokens: ['привсех', ':)', ':)']
# Empty tokens: ['мa', 'chère']
# Empty tokens: [':-)']
# Empty tokens: ['golitsyn', ':)']
# Empty tokens: [':)']
# Empty tokens: ['"', '"']
# Empty tokens: ['накрутите']
# Empty tokens: ['ракович', 'оторветесь']
# Empty tokens: ['хуйняя']
# Empty tokens: ['дансить']
# Empty tokens: ['ипануться']
# Empty tokens: ['неразумности']
# Empty tokens: ['русо', '"', '"']
# Empty tokens: ['"', '"']
# Empty tokens: ['бздю']
# Empty tokens: ['маленькиййог']
# Empty tokens: ['коменикабельный', '3752983339']
# Empty tokens: ['вадьz']
# Empty tokens: ['"', '"', 'одноместные', 'натальяхорева', 'татьянаиванова', 'суперскорости']
# Empty tokens: ['олололололо']
# Empty tokens: ['юююххууу']
# Empty tokens: ['ухахахаххахахахахахахахах', 'ухахаа']
# Empty tokens: ['id10186595']
# Empty tokens: ['слежуу']
# Empty tokens: ['ражденный']
# Empty tokens: [':)']
# Empty tokens: ['миллиончика', 'энергичней']
# Empty tokens: ['"', '"']
# Empty tokens: ['=)']
# Empty tokens: ['неустойчивом', 'tort_m', 'irina']
# Empty tokens: [':)']
# Empty tokens: ['"', '"']
# Empty tokens: ['буксовый']
# Empty tokens: ['<^', '^>', 'увсе', '<^', '^>']
# Empty tokens: ['оставшысь']
# Empty tokens: ['"', '"']
# Empty tokens: ['непрекращающее', '"', '"', 'паралельные']
# Empty tokens: ['вичушек']
# Empty tokens: ['=)']
# Empty tokens: [':)']
# Empty tokens: ['соцопросах']
# Empty tokens: ['"', '"']
# Empty tokens: ['зайцева']
# Empty tokens: ['кельта']
# Empty tokens: ['пася', 'всепроникновенного']
# Empty tokens: ['бредяяятина']
# Empty tokens: ['отрадном']
# Empty tokens: ['шлимана']
# Empty tokens: ['момэнт']
# Empty tokens: ['"', '"']
# Empty tokens: ['канадское']
# Empty tokens: ['перепаять']
# Empty tokens: ['фэнди']
# Empty tokens: ['июньнасрадует']
# Empty tokens: ['id371559']
# Empty tokens: ['=)']
# Empty tokens: ['ништяяяк']
# Empty tokens: ['бартенева']
# Empty tokens: ['антивозрастным', 'эхинацеей']
# Empty tokens: [':)']
# Empty tokens: ['супермэном']
# Empty tokens: [':)']
# Empty tokens: [':)']
# Empty tokens: ['прибалтика']
# Empty tokens: ['34222']
# Empty tokens: ['рeбятa', 'читaйтe']
# Empty tokens: ['корейщины']
# Empty tokens: ['ясей']
# Empty tokens: ['алцест']
# Empty tokens: ['"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"']
# Empty tokens: ['гаданию']
# Empty tokens: ['кошмарчиков', 'morgul', 'hex', 'мультиинструменталиста', 'ripper', 'rade', '"', 'murderer', '"', 'morgul', 'ulver', 'arcturus']
# Empty tokens: ['вовчика']
# Empty tokens: ['душище', ':-)']
# Empty tokens: ['екатеринбрг']
# Empty tokens: ['басиками']
# Empty tokens: [':)']
# Empty tokens: ['убагойтесь']
# Empty tokens: [':)']
# Empty tokens: ['добовляеш']
# Empty tokens: ['современом', 'скептецизмом']
# Empty tokens: ['litlle']
# Empty tokens: ['бытьсчастливыми']
# Empty tokens: ['2еее', 'местооо']
# Empty tokens: ['риальнаво']
# Empty tokens: ['пиздло']
# Empty tokens: ['перемотками']
# Empty tokens: ['мухачев']
# Empty tokens: ['дьюса']
# Empty tokens: ['тамблера']
# Empty tokens: ['откинули']
# Empty tokens: ['братиииш']
# Empty tokens: ['насюша', 'класивая']
# Empty tokens: ['обииделась']
# Empty tokens: ['=)']
# Empty tokens: ['дописывайте']
# Empty tokens: ['приблудилось']
# Empty tokens: ['взраслая', 'силушек']
# Empty tokens: ['проклятущий']
# Empty tokens: ['покачиваний', 'покачивания', 'sculpt']
# Empty tokens: ['фкс']
# Empty tokens: ['куала', 'лумпурские']
# Empty tokens: ['гвоздильщик']
# Empty tokens: ['покореженном']
# Empty tokens: ['pickic', '"', 'малюшкин', '"']
# Empty tokens: ['инсценируй']
# Empty tokens: ['иришей', 'иришей']
# Empty tokens: ['id16807868']
# Empty tokens: ['нымме', 'калью']
# Empty tokens: [':(']
# Empty tokens: ['ахахахахахаахахахх']
# Empty tokens: ['гамашки', 'комбенизон']
# Empty tokens: ['уставшие_птиченьки']
# Empty tokens: ['некисло']
# Empty tokens: ['таварам']
# Empty tokens: [':)', 'рые', ':)']
# Empty tokens: ['нтмпииити', '5меиттт', 'очутт', 'тоь', 'ьто', 'ипн', 'амиотто', 'риж']
# Empty tokens: ['ясноглазая']
# Empty tokens: ['соершенство']
# Empty tokens: ['давидом', 'чиркиняном', 'лутшым', 'поддержывал', 'взорвёмся', 'присвя', 'чено', 'давиду', 'черкиняну']
# Empty tokens: [':-)']
# Empty tokens: [':)']
# Empty tokens: ['малосольных', '=)']
# Empty tokens: ['=)']
# Empty tokens: ['дохренищща', 'артику']
# Empty tokens: [':)']
# Empty tokens: ['остававшиеся']
# Empty tokens: [':)']
# Empty tokens: ['"', '"', 'рэдклиффа', 'нешестнадцатилентяя', '"', '"', 'киношных']
# Empty tokens: ['=)']
# Empty tokens: ['ильзира']
# Empty tokens: ['лиссабона']
# Empty tokens: ['проверочной', 'параграфу', 'дрвнем', '=)']
# Empty tokens: [':)']
# Empty tokens: ['малосольного']
# Empty tokens: ['добряка', 'залупаться']
# Empty tokens: ['проклевываться', 'янеумеювыдумыватьхештэги']
# Empty tokens: ['толерастам']
# Empty tokens: ['таур', 'былинные', 'полигонной', 'несмышленого', '"', '"']
# Empty tokens: ['преличный']
# Empty tokens: ['заааинька', 'мнооога']
# Empty tokens: ['бланд', 'гейме', 'фаинкс', 'свег']
# Empty tokens: ['кокосе']
# Empty tokens: ['dreamfall']
# Empty tokens: ['id2015960', 'serejka', 'podvodny', 'id1582242', 'крыжановская', 'id822148', 'лемеш']
# Empty tokens: ['отмечающийся']
# Empty tokens: ['"', '"', '"', '"', '"', '"', '"', '"']
# Empty tokens: ['подстольной', 'неподцензурной', '"', '"']
# Empty tokens: ['уменянормальновсё']
# Empty tokens: [':*:', ':*:', ':*:']
# Empty tokens: ['порыбачил']
# Empty tokens: ['брусникин']
# Empty tokens: ['збогойздвие', 'збогойно']
# Empty tokens: ['=)']
# Empty tokens: ['ифон', 'перископом']
# Empty tokens: ['зееелеееный', 'кааампот']
# Empty tokens: ['"', '"']
# Empty tokens: [':)']
# Empty tokens: ['аснова']
# Empty tokens: [':)']
# Empty tokens: ['скучание', 'навёрстывание']
# Empty tokens: ['розказ']
# Empty tokens: ['фибия']
# Empty tokens: ['lh']
# Empty tokens: ['эталонное']
# Empty tokens: ['сосиськааа']
# Empty tokens: [':)']
# Empty tokens: ['тянку']
# Empty tokens: [':)']
# Empty tokens: ['здадим']
# Empty tokens: ['скулачёва']
# Empty tokens: ['"', '"', 'кавказки', 'завернута']
# Empty tokens: ['человечеку']
# Empty tokens: ['френдить']
# Empty tokens: ['сверка']
# Empty tokens: ['"', '"']
# Empty tokens: ['"', '"']
# Empty tokens: ['праздравля', 'литпоприще', ':)']
# Empty tokens: ['вваливания', ':)']
# Empty tokens: ['палестинская', 'корпусы', 'гранатах']
# Empty tokens: [':)', ':(']
# Empty tokens: ['палоча']
# Empty tokens: ['"', '"']
# Empty tokens: ['помнеть']
# Empty tokens: ['приежджяет']
# Empty tokens: ['люксовый', 'обезьяник', 'девовочек', 'засекркченна']
# Empty tokens: ['амахасла', 'id161266232', 'христианна', 'карая']
# Empty tokens: [':)']
# Empty tokens: ['шидвр']
# Empty tokens: ['электрокроссовер', 'е6']
# Empty tokens: ['фоткаца', ':)']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"']
# Empty tokens: ['этоонизачемтаксделали']
# Empty tokens: ['пигментированных', 'кремово', 'сливочную']
# Empty tokens: ['"', '"']
# Empty tokens: ['зднём']
# Empty tokens: ['бубончики']
# Empty tokens: ['рейхсмарок']
# Empty tokens: [':)']
# Empty tokens: ['=)', '=)']
# Empty tokens: ['афонасий']
# Empty tokens: ['угорела']
# Empty tokens: ['"', 'olympia', '"']
# Empty tokens: ['=)']
# Empty tokens: ['хeлоу', 'нeжный']
# Empty tokens: ['выщипай', 'винигрета', 'настрогай']
# Empty tokens: ['заветно', 'презаветных']
# Empty tokens: ['=)']
# Empty tokens: ['аеку']
# Empty tokens: ['поросячьи', 'армми', 'донбасовцев', 'азовцев', 'донбасовцев', 'металическими', 'росиийской']
# Empty tokens: ['=)']
# Empty tokens: ['тролиинга', 'магура', 'чепурная']
# Empty tokens: ['даааш', 'кубинца']
# Empty tokens: [':)']
# Empty tokens: ['банкетом', 'апексу']
# Empty tokens: [';)']
# Empty tokens: ['котеджный']
# Empty tokens: ['"', '"']
# Empty tokens: ['=)', '=)']
# Empty tokens: ['журы']
# Empty tokens: ['"', '"', '"', '"']
# Empty tokens: ['повышающийся', 'понижающийся']
# Empty tokens: ['=)']
# Empty tokens: ['арабэск', 'пыжок']
# Empty tokens: [':)']
# Empty tokens: ['=)']
# Empty tokens: ['"', '"', ':)']
# Empty tokens: ['радилась', ':)']
# Empty tokens: ['🏻']
# Empty tokens: ['аргентинские']
# Empty tokens: ['диточкам']
# Empty tokens: ['тиа', 'tvernews']
# Empty tokens: ['уаи', 'гитовича']
# Empty tokens: [';)']
# Empty tokens: ['suppub', 'ozrock']
# Empty tokens: ['id137736308', '"', '"', '5928160', '"', '"']
# Empty tokens: ['нуфвсё', 'гамовер', 'маджистер']
# Empty tokens: ['выхуярила', 'гранулами', 'амиака', 'овиваясь', 'зловонием', 'прокаженным']
# Empty tokens: ['празднкиом']
# Empty tokens: ['кривбассе', 'на4але']
# Empty tokens: ['кшод', 'аркгаркгаи']
# Empty tokens: ['-)']
# Empty tokens: ['красаваа']
# Empty tokens: ['אימון', 'קרב', 'מגע', 'מתקדם', 'ביחידה', 'מובחרת', 'krav']
# Empty tokens: [':)']
# Empty tokens: ['попереписувались', 'ааахххаааххх']

# %%
X_test_scale = embeddings.scaler.transform(X_test)

# %%
preds = mlmodel.model.predict(X_test_scale)

# %%
y_preds = []
for pred in preds:
    max_pred = max(pred)
    max_pred_position = np.where(pred==max_pred)[0][0]
    y_preds.append(mlmodel.mlb.classes_[max_pred_position])

# %%
label_encoder = joblib.load(str(DATA_DIR.joinpath('label_encoder.pkl')))

# %%
y_test = label_encoder.transform(labels_test)
y_preds_encode = label_encoder.transform(y_preds)

# %%
y_true = y_test
y_pred = y_preds_encode

accuracy = accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='weighted', pos_label=1)
precision = precision_score(y_true, y_pred, average='weighted', pos_label=1)
recall = recall_score(y_true, y_pred, average='weighted', pos_label=1)

print('MLP model: \n accuracy - %s, \n f1 - %s, \n precision - %s, \n recall - %s' % (accuracy, f1, precision, recall))
# Out:
# MLP model:
#  accuracy - 0.745871250421301,
#  f1 - 0.7385383169719454,
#  precision - 0.7402676596273022,
#  recall - 0.745871250421301
